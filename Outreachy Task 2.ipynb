# %% [markdown]
# # Automatically matching new Wikipedia articles with Wikidata items using Python - Task 2
#
# In this notebook:
# 1. We logged into our Wikimedia account after setting up pywikibot and user-config.py as per instructions
# 2. Connected to Wikidata
# 3. Printed the Wikidata page for our [previous task](https://www.wikidata.org/wiki/User:A1exGP/Outreachy_1)
# 4. Added 'hello' at the end of the same page
# 5. Created a function that loads a Wikidata item and prints specified statements including qualifiers
#
# 6. Created a function that adds statements to an item
# 7. Created a function that adds qualifiers to statements
#
# All the changes made to Wikidata items have been reverted so  the scripts can be tested again.

# %%
import pywikibot
from textwrap import indent
# Indent allows to indent multi-line strings

# Connect to enwiki
enwiki = pywikibot.Site('en', 'wikipedia')
# and then to wikidata
enwiki_repo = enwiki.data_repository()

pywikibot.Site().login()

# %%
def item_page(qid=str):
    return pywikibot.ItemPage(enwiki_repo, qid)

def data_page(url=str):
    return pywikibot.Page(enwiki_repo, url)

def property_page(pid=str):
    return pywikibot.PropertyPage(enwiki_repo, 'Property:' + pid)

def wiki_claim(pid=str):
    return pywikibot.Claim(enwiki_repo, pid)

def print_page(url=str):
    print(data_page(url).text)

# %%
print_page('User:A1exGP/Outreachy_1')
# Out:
# = Deserts =
#
# Notes:
#
# Properties were listed in the order they appeared in the Wikidata item.
#
# There were some properties that had multiple values both in article and data page. Only the first one was included.
#
# Articles where selected with diversity in mind. Some of them where taken from [[:en:List of deserts by area]]. At least one desert from each type was chosen, as well as at least one from North America, South America, Europe, Australia, Western Asia, Eastern Asia, Northern Africa, Southern Africa each.
#
# ===== Properties used =====
#
# *{{P|P17}}
# *{{P|P18}}
# *{{P|P30}}
# *{{P|P31}}
# *{{P|P131}}
# *{{P|P242}}
# *{{P|P361}}
# *{{P|P610}}
# *{{P|P625}}
# *{{P|P948}}
# *{{P|P1425}}
# *{{P|P1589}}
# *{{P|P2043}}
# *{{P|P2044}}
# *{{P|P2046}}
# *{{P|P2049}}
#
# Unique properties listed: 16. Counting qualifiers: 18
#
# *{{P|P518}}
# *{{P|P2096}}
#
# Qualifiers allow to expand on the information that can be displayed in simple property-value pairs. They are attached to values and include a property and value themselves. These were included in any values that had them.
#
#
# ===== Sahara =====
# * {{P|P31}}: [[:en:Sahara]] is a {{Q|Q8514}} in the description
# * {{P|P18}}: [[:en:Sahara]] has {{File:Sahara satellite hires.jpg}} in the infobox
# ** {{P|P2096}}: [[:en:Sahara]] has 'A satellite image of the Sahara by NASA (English)' as the image legend
# * {{P|P1425}}: [[:en:Sahara]] has {{Q|Q3892981}} in the article body
# * {{P|P30}}: [[:en:Sahara]] is in {{Q|Q15}} in the article body
# * {{P|P17}}: [[:en:Sahara]] is in {{Q|Q262}} in the article body
# * {{P|P625}}: [[:en:Sahara]] has coordinates 23°4'47"N, 12°36'44"E in the infobox
# * {{P|P610}}: [[:en:Sahara]] highest point is {{Q|Q257441}} in the article body
# * {{P|P1589}}: [[:en:Sahara]] lowest point is {{Q|Q841050}} in the article body
# * {{P|P2043}}: [[:en:Sahara]] length is 4,800 kilometre in the infobox
# * {{P|P2049}}: [[:en:Sahara]] width is 1,800 kilometre in the article infobox
# * {{P|P2046}}: [[:en:Sahara]] area is 9,200,000 square kilometre in the infobox
#
# ==== Namib ====
# * {{P|P31}}: [[:en:Namib]] is a {{Q|Q8514}} in the description
# * {{P|P18}}: [[:en:Namib]] has {{File:Namib Desert surface.jpg}} in the infobox
# * {{P|P17}}: [[:en:Namib]] is in {{Q|Q1030}} in the article body
# * {{P|P625}}: [[:en:Namib]] has coordinates 23°0'0"S, 15°0'0" at the top of the page
# * {{P|P2043}}: [[:en:Namib]] length is 2,000 kilometre in the description
# * {{P|P2046}}: [[:en:Namib]] area is 3,077,700 hectare in the infobox
#
# ==== Arabian Desert ====
# * {{P|P31}}: [[:en:Arabian Desert]] is a {{Q|Q8514}} in the description
# * {{P|P361}}: [[:en:Arabian Desert]] is part of {{Q|Q205895}} in the article body
# * {{P|P18}}: [[:en:Arabian Desert]] has {{File:Arabian Desert - panoramio.jpg}} in the infobox
# * {{P|P17}}: [[:en:Arabian Desert]] is in {{Q|Q851}} in the article body
# * {{P|P30}}: [[:en:Arabian Desert]] is in {{Q|Q48}} in the description
# ** {{P|P518}}: [[:en:Arabian Desert]] is in {{Q|Q27293}} in the description
# * {{P|P2046}}: [[:en:Arabian Desert]] area is 2,330,000 square kilometre in the description
# * {{P|P242}}: [[:en:Arabian Desert]] has {{File:Arabian Desert.jpg}} in the article body
#
# ==== Gobi Desert ====
# * {{P|P31}}: [[:en:Gobi Desert]] is a {{Q|Q8514}} in the description
# * {{P|P17}}: [[:en:Gobi Desert]] is in {{Q|Q48}} in the article body
# * {{P|P30}}: [[:en:Gobi Desert]] is in {{Q|Q148}} in the article body
# * {{P|P625}}: [[:en:Gobi Desert]] has coordinates 42°30'N, 103°0'E in the infobox
# * {{P|P2043}}: [[:en:Gobi Desert]] length is 1,500 kilometre in the article body
# * {{P|P242}}: [[:en:Gobi Desert]] has {{File:China edcp relief location map Gobi de.jpg}} in the infobox
#
# ==== Sonoran Desert ====
# * {{P|P31}}: [[:en:Sonoran Desert]] is a {{Q|Q8514}} in the description
# * {{P|P17}}: [[:en:Sonoran Desert]] is in {{Q|Q30}} in the infobox
# * {{P|P131}}: [[:en:Sonoran Desert]] is in {{Q|Q816}} in the infobox
# * {{P|P625}}: [[:en:Sonoran Desert]] has coordinates 32°15'36"N, 112°55'34"W at the top of the page
# * {{P|P2046}}: [[:en:Sonoran Desert]] area is 2260,000 square kilometre in the description
#
# ==== Atacama Desert ====
# * {{P|P31}}: [[:en:Atacama Desert]] is a {{Q|Q8514}} in the description
# * {{P|P18}}: [[:en:Atacama Desert]] has {{File:Sahara satellite hires.jpg}} in the infobox
# * {{P|P17}}: [[:en:Atacama Desert]] is in {{Q|Q298}} in the infobox
# * {{P|P625}}: [[:en:Atacama Desert]] has coordinates 24°30'S, 69°15'W in the infobox
# * {{P|P2044}}: [[:en:Atacama Desert]] elevation is 2,657 metre in the article body
# * {{P|P2046}}: [[:en:Atacama Desert]] area is 105,000 square kilometre in the description
# * {{P|P242}}: [[:en:Atacama Desert]] has {{File:Atacama_map.svg}} in the infobox
#
# ==== Tabernas Desert ====
# * {{P|P31}}: [[:en:Tabernas Desert]] is a {{Q|Q8514}} in the description
# * {{P|P18}}: [[:en:Tabernas  Desert]] has {{File:Almeria 02.jpg}} in the infobox
# * {{P|P17}}: [[:en:Tabernas  Desert]] is in {{Q|Q29}} in the infobox
# * {{P|P131}}: [[:en:Tabernas  Desert]] is in {{Q|Q81802}} in the infobox
# * {{P|P625}}: [[:en:Tabernas  Desert]] has coordinates 37°0'N, 2°27'W in the infobox
#
# ==== Great Victoria Desert ====
# * {{P|P31}}: [[:en:Great Victoria Desert]] is a {{Q|Q8514}} in the description
# * {{P|P18}}: [[:en:Great Victoria  Desert]] has {{File:Australia.A2002231.0145.250m NASA Nullarbor.jpg}} in the article body
# * {{P|P17}}: [[:en:Great Victoria  Desert]] is in {{Q|Q408}} in the infobox
# * {{P|P131}}: [[:en:Great Victoria  Desert]] is in {{Q|Q3206}} in the infobox
# * {{P|P625}}: [[:en:Great Victoria  Desert]] has coordinates 29°9'8"S, 129°15'35"E at the top of the page
# * {{P|P2046}}: [[:en:Great Victoria  Desert]] area is 424,400 square kilometre in the infobox
# * {{P|P242}}: [[:en:Great Victoria Desert]] has {{File:IBRA 6.1 Great Victoria Desert.png}} in the infobox
#
# ==== Arctic desert ====
# * {{P|P31}}: [[:en:Arctic desert]] is a {{Q|Q8514}} in the description
# * {{P|P18}}: [[:en:Arctic desert]] has {{File:Вид на остров Бэлл.jpg}} in the infobox
# * {{P|P17}}: [[:en:Arctic desert]] is in {{Q|159}} in the infobox
# * {{P|P625}}: [[:en:Arctic desert]] has coordinates 81°0'0.000"N, 55°0'0.000"E in the infobox
# * {{P|P242}}: [[:en:Arctic desert]] has {{File:Ecoregion PA1101.png}} in the infobox
#
#
# === Additional properties ===
# Additional statements were found for several articles that had no statement in the data items: type of climate, temperature, precipitation, number of flora species, number of fauna species, number of habitants, religion of its habitants, language of its habitants, ecoregions. Others were found investigating articles parallel to our type (e.g. [[:en:Amazon rainforest]]). For those that apply:
#
# * {{P|P361}}
# * {{P|P797}}
# * {{P|P1082}}
# * {{P|P1889}}
# * {{P|P1943}}
# * {{P|P2564}}
# * {{P|P2936}}
# * {{P|P3018}}
#
#
# === Added statements on Wikidata items ===
#
# The following statements were added:
#
# * {{P|P1425}} in [[:en:Gobi Desert]] added to its Wikidata item {{Q|Q42070}}
# * {{P|P2564}} added to {{Q|Q6583}}
# * {{P|P2564}} added to {{Q|Q208299}}
# * {{P|P3018}} added to {{Q|Q189429}}
# * {{P|P2564}} added to {{Q|Q939811}}
# * {{P|P30}} added to {{Q|Q145165}}
# * {{P|P2564}} added to {{Q|Q398398}}
#
# hello
#
# hello
#
# hello

# %%
def add_wikidata_text(url=str, added=str):
    # Adds text at the end of the page in a new line
    # Inputs are the string url after '/wiki/' and the added text
    page = data_page(url)    
    page.text = page.text + '\n\n' + added
    
    try:
        page.save("Text added through pywikibot")
    except:
        print('Error. Please check log in status.')
    
add_wikidata_text('user:A1exGP/Outreachy_1', 'hello')
# Out:
# Sleeping for 8.7 seconds, 2021-11-04 13:56:12
# Page [[wikidata:User:A1exGP/Outreachy 1]] saved

# %%
def print_wikidata_p(item_page=str, n = False):
    # We'll access this dic a number of times
    item_dict = item_page.get() 
    
    print(item_page.title() + ' ' + item_dict['labels']['en'])
    print('\n+++++++++++++++++++++++++++++++')
    print('-------------------------------')
    
    # Create a list of all the P numbers from our item page
    if n == False:
        props = [prop for prop in item_dict['claims']]
    # Work with passed list of P numbers
    elif type(n) == list:
        props = n
    # Lastly, use the first n properties
    elif type(n) == int:
        props = [prop for prop in item_dict['claims']][:n]
    else:
        print('Error. Please check the property list.')
        return 0
    
    for prop in props:        
        try:
            # Retrieve the property page object and extract the name
            # Printing just the P number is a faster, less descriptive alternative
            prop_page = property_page(prop)
            prop_label = prop_page.labels['en']
            print(prop + ' ' + prop_label)
            
            for claim in item_dict['claims'][prop]:
                # There are two scenarios: the value is a data item or not
                # Try to print the value Q number and label
                try:
                    qid = claim.getTarget().title()
                    label = claim.getTarget().labels['en']
                    print(qid + ' ' + label)
                # Else print the value object as is
                except:
                    print(claim.getTarget())
                    
                # Getting the qualifiers when relevant
                # Code is analogous to the regular statements
                if claim.qualifiers:
                    for qprop, qvalues in claim.qualifiers.items():
                        qprop_page = property_page(qprop)
                        qprop_label = qprop_page.labels['en']
                        print(indent(qprop + ' ' + qprop_label, '     '))
                        for qvalue in qvalues:
                            # Same distinction. Qualifier value might be an item or not
                            try:
                                qid = qvalue.getTarget().title()
                                label = claim.getTarget().labels['en']
                                print(indent(str(qid) + ' ' + str(label), '     '))
                            except:
                                print(indent(str(qvalue.getTarget()), '     '))
                    
            print('-------------------------------')
            print('-------------------------------')
            
        except:
            print('Error. Please check the property list.')
            break
            
        # The outer try can fail because: an element of props isn't a valid string P number,
        # or one of the P numbers isn't a key in item_dict['claims'] a.k.a that property can't be found
        # in our passed item page.
        
# Calling the function by a string is more intuitive
def print_wikidata(s, n = False):
    page = pywikibot.ItemPage(enwiki_repo, s)
    
    return print_wikidata_p(page, n)

# %%
# First 2 statements from Sahara
print_wikidata('Q6583',2)
print('\n')

# Sandbox with qualifier
print_wikidata('Q4115189',['P735', 'P7763'])
# Out:
# Q6583 Sahara
#
# +++++++++++++++++++++++++++++++
# -------------------------------
# P31 instance of
# Q8514 desert
# -------------------------------
# -------------------------------
# P30 continent
# Q15 Africa
# -------------------------------
# -------------------------------
#
#
# Q4115189 Wikidata Sandbox
#
# +++++++++++++++++++++++++++++++
# -------------------------------
# P735 given name
# Q1242905 Penelope
# -------------------------------
# -------------------------------
# P7763 copyright status as a creator
# Q73555012 works protected by copyrights
#      P1001 applies to jurisdiction
#      Q87048619 works protected by copyrights
# -------------------------------
# -------------------------------

# %%
def add_statement(qid=str, pid=str, value=str, value_type = 's'):
    # We will consider 2 scenarions: value_type = 's' for a string and 'q' for an item
    item = item_page(qid)
    claim = wiki_claim(pid)
    
    if value_type == 'q':
        try:
            target = item_page(value)
            claim.setTarget(target)
            item.addClaim(claim, summary=u'pywikibot test Outreachy')
            print(pid + ':' + value + ' added to ' + qid)
        except:
            print('Error. Please check value QID or credentials')
            
    if value_type == 's':
        try:
            target = pywikibot.WbMonolingualText(value,'en')
            claim.setTarget(target)
            item.addClaim(claim, summary=u'pywikibot test Outreachy')
            print(pid + ':' + value + ' added to ' + qid)
        except:
            print('Error. Please check credentials')

# %%
# Adding Occupation:Educator and Title:Wikipedia Sandbox
add_statement('Q4115189', 'P106', 'Q974144', 'q')
add_statement('Q4115189', 'P1476', 'Wikipedia Sandbox', 's')
# Out:
# Sleeping for 4.2 seconds, 2021-11-04 13:56:26
# P106:Q974144 added to Q4115189
# Sleeping for 9.1 seconds, 2021-11-04 13:56:31
# P1476:Wikipedia Sandbox added to Q4115189

# %%
def add_qualifier(qid=str, pid1=str, value1=str, pid2=str, value2=str):
    # Similar to previous function with item values, but now we take outer and inner pids 
    item = item_page(qid)
    # We look for a the speficic property-value pair pid1-value1.
    for claim in item.claims[pid1]: 
        if claim.getTarget().title() == value1:
            qualifier = wiki_claim(pid2)
            target = item_page(value2)
            qualifier.setTarget(target)
            claim.addQualifier(qualifier, summary=u'pywikibot test Outreachy')
            print(pid2 + ':' + value2 + ' added to ' + pid1 + ':' + value1 + ' in ' + qid)

# %%
print_wikidata('Q4115189',['P31'])
print('\n')

# We are looking for the P31:Q95074 statement in Q4115189
# If it exists, add a qualifier P1080:Q171
add_qualifier(qid = 'Q4115189', pid1 = 'P31', value1 = 'Q95074', pid2 = 'P1080', value2 = 'Q171')
print('\n')

print_wikidata('Q4115189',['P31'])
# Out:
# Q4115189 Wikidata Sandbox
#
# +++++++++++++++++++++++++++++++
# -------------------------------
# P31 instance of
# Q95074 fictional character
# -------------------------------
# -------------------------------
# Sleeping for 7.7 seconds, 2021-11-04 13:56:43
# P1080:Q171 added to P31:Q95074 in Q4115189
#
#
# Q4115189 Wikidata Sandbox
#
# +++++++++++++++++++++++++++++++
# -------------------------------
# P31 instance of
# Q95074 fictional character
#      P1080 from narrative universe
#      Q171 fictional character
# -------------------------------
# -------------------------------
